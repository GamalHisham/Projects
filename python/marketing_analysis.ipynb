# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_excel('/content/drive/My Drive/Data/marketing_anlysis.xlsx')

# %%
df.sample(5)
# Out:
#      Campaign       Date City/Location    Channel   Device          Ad  \
# 5044  Summer  2023-06-03    Birmingham   Facebook   Mobile  Collection
# 1798  Summer  2023-07-27    Birmingham  Instagram  Desktop  Collection
# 1096    Fall  2023-11-27    Birmingham   Facebook  Desktop    Discount
# 5061  Summer  2023-06-20    Birmingham   Facebook   Mobile  Collection
# 3730  Summer  2023-08-03        London  Pinterest  Desktop  Collection
#
#       Impressions     Clicks  Daily Average CPC  Spend, Dollars  Conversions  \
# 5044       1174.6  13.625360             0.4000        5.450144            2
# 1798        879.8  14.323144             0.2645        3.788472            4
# 1096       1471.0  18.828800             1.9665       37.026835            2
# 5061       1447.5  12.738000             1.0200       12.992760            4
# 3730        817.2  10.133280             0.2300        2.330654            1
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9900 entries, 0 to 9899
# Data columns (total 16 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Campaign                         9900 non-null   object
#  1   Date                             9900 non-null   datetime64[ns]
#  2   City/Location                    9900 non-null   object
#  3   Channel                          9900 non-null   object
#  4   Device                           9900 non-null   object
#  5   Ad                               9900 non-null   object
#  6   Impressions                      9900 non-null   float64
#  7   Clicks                           9900 non-null   float64
#  8   Daily Average CPC                9900 non-null   float64
#  9   Spend, Dollars                   9900 non-null   float64
#  10  Conversions                      9900 non-null   int64
# ...

# %%
df.describe()
# Out:
#                       Date  Impressions       Clicks  Daily Average CPC  \
# count                 9900  9900.000000  9900.000000        9900.000000
# mean   2023-07-16 00:00:00  1479.338263    18.342022           0.903973
# min    2023-03-01 00:00:00     1.000000     0.000000           0.000000
# 25%    2023-05-08 00:00:00  1025.275000    10.797730           0.471500
# 50%    2023-07-16 00:00:00  1436.750000    17.013264           0.840000
# 75%    2023-09-23 00:00:00  1910.025000    24.667050           1.232875
# max    2023-11-30 00:00:00  3847.000000    61.571620           2.691000
# std                    NaN   660.540407    10.246853           0.562639
#
#        Spend, Dollars  Conversions  Total conversion value, Dollars  \
# count     9900.000000  9900.000000                      9900.000000
# mean        16.489906     4.065859                       174.919236
# min          0.000000     0.000000                         0.000000
# ...

# %%
sns.scatterplot(x='Spend, Dollars',y='Total conversion value, Dollars',data=df)
# Out:
# <Axes: xlabel='Spend, Dollars', ylabel='Total conversion value, Dollars'>

# %%
# sns.histplot(x='Campaign',data=df)

# %%
sns.barplot(x='City/Location',data=df,y='Total conversion value, Dollars')
# Out:
# <Axes: xlabel='City/Location', ylabel='Total conversion value, Dollars'>
